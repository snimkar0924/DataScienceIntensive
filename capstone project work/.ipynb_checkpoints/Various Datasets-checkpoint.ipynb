# %% [markdown]
# ## This file loads a number of datasets to inspect these for use in data analysis.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Sales Opportunity Win-Loss Data

# %%
salesData = pd.read_csv('./data/WA_Fn-UseC_-Sales-Win-Loss.csv')

# %%
salesData.head()
# Out:
#    Opportunity Number     Supplies Subgroup          Supplies Group  \
# 0             1641984  Exterior Accessories         Car Accessories
# 1             1658010  Exterior Accessories         Car Accessories
# 2             1674737      Motorcycle Parts  Performance & Non-auto
# 3             1675224         Shelters & RV  Performance & Non-auto
# 4             1689785  Exterior Accessories         Car Accessories
#
#       Region Route To Market  Elapsed Days In Sales Stage Opportunity Result  \
# 0  Northwest    Fields Sales                           76                Won
# 1    Pacific        Reseller                           63               Loss
# 2    Pacific        Reseller                           24                Won
# 3    Midwest        Reseller                           16               Loss
# 4    Pacific        Reseller                           69               Loss
#
#    Sales Stage Change Count  Total Days Identified Through Closing  \
# ...

# %% [markdown]
# ### Grocery Store Marketing Campaign Data

# %%
cmpgData = pd.read_csv("./data/WA_Fn-UseC_-Marketing-Campaign-Plan_-GroceryS.csv")

# %%
cmpgData.head()
# Out:
#    storeid   HealthyStore StoreSize  StoreLayout  customerID gender  \
# 0        1  Regular store    Medium  No emphasis  6193-QDKCN   Male
# 1        1  Regular store    Medium  No emphasis  6193-QDKCN   Male
# 2        1  Regular store    Medium  No emphasis  6193-QDKCN   Male
# 3        1  Regular store    Medium  No emphasis  6193-QDKCN   Male
# 4        1  Regular store    Medium  No emphasis  9245-DEZSB   Male
#
#     WhoShoppingFor Vegetarian          ShoppingStyle      CouponUser  week  \
# 0  Self and spouse         No  Often; what's on sale  From newspaper     1
# 1  Self and spouse         No  Often; what's on sale  From newspaper     2
# 2  Self and spouse         No  Often; what's on sale  From newspaper     3
# 3  Self and spouse         No  Often; what's on sale  From newspaper     4
# 4  Self and family         No  Weekly; similar items   From mailings     1
#
#   CouponSequence  CarryOver  CouponValue  AmountSpent
# ...

# %% [markdown]
# ### Customer Value Analysis Data

# %%
plcyData = pd.read_csv("./data/WA_Fn-UseC_-Marketing-Customer-Value-Analysis.csv")

# %%
plcyData.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income     ...       \
# 0           2/24/11         Employed      F   56274     ...
# 1           1/31/11       Unemployed      F       0     ...
# 2           2/19/11         Employed      F   48767     ...
# 3           1/20/11       Unemployed      M       0     ...
# 4            2/3/11         Employed      M   43836     ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...
